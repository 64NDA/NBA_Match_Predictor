# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from random import randint

# Step 1: Send an HTTP request to the website (replace with the URL of the page with the table you want to scrape)
url = 'https://www.basketball-reference.com/leagues/NBA_2024_games-january.html'
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    print('Successfully fetched the webpage')
else:
    print('Failed to fetch the webpage:', response.status_code)
    exit()
# Out:
# Successfully fetched the webpage

# %%
# Step 2: Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Step 3: Find the table in the HTML (by id, class, or tag)
# In this case, let's assume we are looking for a table with the id 'schedule'
table = soup.find('table', {'id': 'schedule'})

# Step 4: Extract the table headers (if needed)
headers = []
for th in table.find('thead').find_all('th'):
    headers.append(th.text.strip())

# Step 5: Extract the table rows
rows = []
for row in table.find('tbody').find_all('tr'):
    row_data = []
    for cell in row.find_all(['th', 'td']):
        row_data.append(cell.text.strip())
    
 # Step 6: Find the specific <td> tag with data_stat="box_score_text"
    boxscore_td = row.find('td', {'data-stat': 'box_score_text'})
    
    # Extract the box score link if it exists
    if boxscore_td:
        boxscore_link = boxscore_td.find('a', href=True)
        if boxscore_link and boxscore_link.text == 'Box Score':  # Ensure it's the correct link
            row_data.append('https://www.basketball-reference.com' + boxscore_link['href'])
        else:
            row_data.append(None)  # If no link or incorrect, append None
    else:
        row_data.append(None)
    
    rows.append(row_data)

# Step 7: Convert the scraped data into a DataFrame
headers.append('Boxscore Link')  # Add the boxscore link as a new column
df = pd.DataFrame(rows, columns=headers)

# Step 8: Save the DataFrame to a CSV file
df.to_csv('basketball_games_with_boxscores.csv', index=False)

print('Scraping completed and data saved to CSV!')
# Out:
# Scraping completed and data saved to CSV!

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Function to scrape advanced box score data from a given boxscore link
def scrape_advanced_boxscore_data(boxscore_url, data_stats):
    # Send a GET request to the boxscore page
    response = requests.get(boxscore_url)
    if response.status_code != 200:
        print(f"Failed to fetch boxscore at {boxscore_url}")
        return None
    
    # Parse the HTML content of the boxscore page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Initialize two dictionaries to store the scraped data for Team 1 and Team 2
    boxscore_data_team1 = {}
    boxscore_data_team2 = {}

    try:
        # Step 1: Locate both tables that contain "Advanced Box Score Stats" in <th>
        advanced_tables = []
        
        # Find all <th> tags with the class "over_header center" and text "Advanced Box Score Stats"
        th_tags = soup.find_all('th', class_='over_header center', string='Advanced Box Score Stats')
        
        if not th_tags:
            print(f"No <th> tags found with class 'over_header center' and text 'Advanced Box Score Stats' for {boxscore_url}")
            return None

        # Step 2: Find the parent <table> for each matching <th> and add to advanced_tables
        for th in th_tags:
            table = th.find_parent('table')
            if table:
                advanced_tables.append(table)

        if len(advanced_tables) < 2:
            print(f"Expected 2 advanced box stats tables but found {len(advanced_tables)} for {boxscore_url}")
            return None
        
        
        # Step 2: Extract data from the first table (Team 1)
        tfoot_team1 = advanced_tables[0].find('tfoot')
        if tfoot_team1:
            for td in tfoot_team1.find_all('td'):
                data_stat = td.get('data-stat')
                if data_stat in data_stats:
                    boxscore_data_team1[f'team1_{data_stat}'] = td.text.strip()
        
        # Step 3: Extract data from the second table (Team 2)
        tfoot_team2 = advanced_tables[1].find('tfoot')
        if tfoot_team2:
            for td in tfoot_team2.find_all('td'):
                data_stat = td.get('data-stat')
                if data_stat in data_stats:
                    boxscore_data_team2[f'team2_{data_stat}'] = td.text.strip()

    except AttributeError as e:
        print(f"Error extracting advanced box score data: {e}")
        return None
    
    # Return combined dictionary for both teams
    return {**boxscore_data_team1, **boxscore_data_team2}

# Main function to load CSV, scrape advanced boxscore data, and update the table
def main():
    # Step 1: Load the CSV file generated from the previous program
    df = pd.read_csv('basketball_games_with_boxscores.csv')

    # Define the data-stat attributes you are interested in
    data_stats = [
        'ts_pct',  # True shooting percentage
        'efg_pct',  # Effective field goal percentage
        'fg3a_per_fga_pct',  # 3-point attempt rate
        'fta_per_fga_pct',  # Free throw attempt rate
        'trb_pct', # Total rebound percentage
        'ast_pct',  # Assist percentage
        'stl_pct',  # Steal percentage
        'blk_pct',  # Block percentage
        'tov_pct',  # Turnover percentage
        'off_rtg',  # Offensive rating
        'def_rtg',  # Defensive rating
        # Add more data-stat attributes as needed
    ]

    # Step 2: Initialize empty lists to store the scraped advanced stats data
    team1_ts_pct = []
    team2_ts_pct = []
    team1_efg_pct = []
    team2_efg_pct = []
    team1_fg3a_per_fga_pct = []
    team2_fg3a_per_fga_pct = []
    team1_fta_per_fga_pct = []
    team2_fta_per_fga_pct = []
    team1_trb_pct = []
    team2_trb_pct = []
    team1_ast_pct = []
    team2_ast_pct = []
    team1_stl_pct = []
    team2_stl_pct = []
    team1_blk_pct = []
    team2_blk_pct = []
    team1_tov_pct = []
    team2_tov_pct = []
    team1_off_rtg = []
    team2_off_rtg = []
    team1_def_rtg = []
    team2_def_rtg = []
    # Add more lists as needed for additional data-stat attributes

    # Step 3: Loop over each row in the CSV file and scrape advanced box score data for each game
    for index, row in df.iterrows():
        boxscore_url = row['Boxscore Link']
        
        if pd.notna(boxscore_url):  # Only scrape if the boxscore link is present
            print(f"Scraping advanced boxscore for game {index + 1} of {len(df)}")
            
            # Scrape advanced box score data from the boxscore page
            advanced_boxscore_data = scrape_advanced_boxscore_data(boxscore_url, data_stats)
            
            # If data was successfully scraped, append it to the respective lists
            if advanced_boxscore_data:
                team1_ts_pct.append(advanced_boxscore_data.get('team1_ts_pct'))
                team2_ts_pct.append(advanced_boxscore_data.get('team2_ts_pct'))
                team1_efg_pct.append(advanced_boxscore_data.get('team1_efg_pct'))
                team2_efg_pct.append(advanced_boxscore_data.get('team2_efg_pct'))
                team1_fg3a_per_fga_pct.append(advanced_boxscore_data.get('team1_fg3a_per_fga_pct'))
                team2_fg3a_per_fga_pct.append(advanced_boxscore_data.get('team2_fg3a_per_fga_pct'))
                team1_fta_per_fga_pct.append(advanced_boxscore_data.get('team1_fta_per_fga_pct'))
                team2_fta_per_fga_pct.append(advanced_boxscore_data.get('team2_fta_per_fga_pct'))
                team1_trb_pct.append(advanced_boxscore_data.get('team1_trb_pct'))
                team2_trb_pct.append(advanced_boxscore_data.get('team2_trb_pct'))
                team1_ast_pct.append(advanced_boxscore_data.get('team1_ast_pct'))
                team2_ast_pct.append(advanced_boxscore_data.get('team2_ast_pct'))
                team1_stl_pct.append(advanced_boxscore_data.get('team1_stl_pct'))
                team2_stl_pct.append(advanced_boxscore_data.get('team2_stl_pct'))
                team1_blk_pct.append(advanced_boxscore_data.get('team1_blk_pct'))
                team2_blk_pct.append(advanced_boxscore_data.get('team2_blk_pct'))
                team1_tov_pct.append(advanced_boxscore_data.get('team1_tov_pct'))
                team2_tov_pct.append(advanced_boxscore_data.get('team2_tov_pct'))
                team1_off_rtg.append(advanced_boxscore_data.get('team1_off_rtg'))
                team2_off_rtg.append(advanced_boxscore_data.get('team2_off_rtg'))
                team1_def_rtg.append(advanced_boxscore_data.get('team1_def_rtg'))
                team2_def_rtg.append(advanced_boxscore_data.get('team2_def_rtg'))
                
            else:
                # If scraping failed, append None to keep the data aligned
                team1_ts_pct.append(None)
                team2_ts_pct.append(None)
                team1_efg_pct.append(None)
                team2_efg_pct.append(None)
                team1_fg3a_per_fga_pct.append(None)
                team2_fg3a_per_fga_pct.append(None)
                team1_fta_per_fga_pct.append(None)
                team2_fta_per_fga_pct.append(None)
                team1_trb_pct.append(None)
                team2_trb_pct.append(None)
                team1_ast_pct.append(None)
                team2_ast_pct.append(None)
                team1_stl_pct.append(None)
                team2_stl_pct.append(None)
                team1_blk_pct.append(None)
                team2_blk_pct.append(None)
                team1_tov_pct.append(None)
                team2_tov_pct.append(None)
                team1_off_rtg.append(None)
                team2_off_rtg.append(None)
                team1_def_rtg.append(None)
                team2_def_rtg.append(None)
                
            
            # Add a delay to avoid overloading the server (polite scraping)
            time.sleep(5)
        else:
            # If no box score link, append None values
            team1_ts_pct.append(None)
            team2_ts_pct.append(None)
            team1_efg_pct.append(None)
            team2_efg_pct.append(None)
            team1_fg3a_per_fga_pct.append(None)
            team2_fg3a_per_fga_pct.append(None)
            team1_fta_per_fga_pct.append(None)
            team2_fta_per_fga_pct.append(None)
            team1_trb_pct.append(None)
            team2_trb_pct.append(None)
            team1_ast_pct.append(None)
            team2_ast_pct.append(None)
            team1_stl_pct.append(None)
            team2_stl_pct.append(None)
            team1_blk_pct.append(None)
            team2_blk_pct.append(None)
            team1_tov_pct.append(None)
            team2_tov_pct.append(None)
            team1_off_rtg.append(None)
            team2_off_rtg.append(None)
            team1_def_rtg.append(None)
            team2_def_rtg.append(None)
    
    # Step 4: Add the scraped data as new columns in the DataFrame
    df['Team 1 TS PCT'] = team1_ts_pct
    df['Team 2 TS PCT'] = team2_ts_pct
    df['Team 1 EFG PCT'] = team1_efg_pct
    df['Team 2 EFG PCT'] = team2_efg_pct
    df['Team 1 3P AR'] = team1_fg3a_per_fga_pct
    df['Team 2 3P AR'] = team2_fg3a_per_fga_pct
    df['Team 1 FT AR'] = team1_fta_per_fga_pct
    df['Team 2 FT AR'] = team2_fta_per_fga_pct
    df['Team 1 TRB PCT'] = team1_trb_pct
    df['Team 2 TRB PCT'] = team2_trb_pct
    df['Team 1 AST PCT'] = team1_ast_pct
    df['Team 2 AST PCT'] = team2_ast_pct
    df['Team 1 STL PCT'] = team1_stl_pct
    df['Team 2 STL PCT'] = team2_stl_pct
    df['Team 1 BLK PCT'] = team1_blk_pct
    df['Team 2 BLK PCT'] = team2_blk_pct
    df['Team 1 TO PCT'] = team1_tov_pct
    df['Team 2 TO PCT'] = team2_tov_pct
    df['Team 1 OFF RT'] = team1_off_rtg
    df['Team 2 OFF RT'] = team2_off_rtg
    df['Team 1 DEF RT'] = team1_def_rtg
    df['Team 2 DEF RT'] = team2_def_rtg

    
    # Step 5: Save the updated DataFrame to a new CSV file
    df.to_csv('2024january.csv', index=False)
    print('Updated data with advanced stats saved to CSV!')

if __name__ == "__main__":
    main()
# Out:
# Scraping advanced boxscore for game 1 of 208
# Scraping advanced boxscore for game 2 of 208
# Scraping advanced boxscore for game 3 of 208
# Scraping advanced boxscore for game 4 of 208
# Scraping advanced boxscore for game 5 of 208
# Scraping advanced boxscore for game 6 of 208
# Scraping advanced boxscore for game 7 of 208
# Scraping advanced boxscore for game 8 of 208
# Scraping advanced boxscore for game 9 of 208
# Scraping advanced boxscore for game 10 of 208
# Scraping advanced boxscore for game 11 of 208
# Scraping advanced boxscore for game 12 of 208
# Scraping advanced boxscore for game 13 of 208
# Scraping advanced boxscore for game 14 of 208
# Scraping advanced boxscore for game 15 of 208
# Scraping advanced boxscore for game 16 of 208
# Scraping advanced boxscore for game 17 of 208
# Scraping advanced boxscore for game 18 of 208
# Scraping advanced boxscore for game 19 of 208
# Scraping advanced boxscore for game 20 of 208
# Scraping advanced boxscore for game 21 of 208
# Scraping advanced boxscore for game 22 of 208
# Scraping advanced boxscore for game 23 of 208
# Scraping advanced boxscore for game 24 of 208
# Scraping advanced boxscore for game 25 of 208
# Scraping advanced boxscore for game 26 of 208
# Scraping advanced boxscore for game 27 of 208
# Scraping advanced boxscore for game 28 of 208
# Scraping advanced boxscore for game 29 of 208
# Scraping advanced boxscore for game 30 of 208
# Scraping advanced boxscore for game 31 of 208
# Scraping advanced boxscore for game 32 of 208
# Scraping advanced boxscore for game 33 of 208
# Scraping advanced boxscore for game 34 of 208
# Scraping advanced boxscore for game 35 of 208
# Scraping advanced boxscore for game 36 of 208
# Scraping advanced boxscore for game 37 of 208
# Scraping advanced boxscore for game 38 of 208
# Scraping advanced boxscore for game 39 of 208
# Scraping advanced boxscore for game 40 of 208
# Scraping advanced boxscore for game 41 of 208
# Scraping advanced boxscore for game 42 of 208
# Scraping advanced boxscore for game 43 of 208
# Scraping advanced boxscore for game 44 of 208
# Scraping advanced boxscore for game 45 of 208
# Scraping advanced boxscore for game 46 of 208
# Scraping advanced boxscore for game 47 of 208
# Scraping advanced boxscore for game 48 of 208
# Scraping advanced boxscore for game 49 of 208
# Scraping advanced boxscore for game 50 of 208
# Scraping advanced boxscore for game 51 of 208
# Scraping advanced boxscore for game 52 of 208
# Scraping advanced boxscore for game 53 of 208
# Scraping advanced boxscore for game 54 of 208
# Scraping advanced boxscore for game 55 of 208
# Scraping advanced boxscore for game 56 of 208
# Scraping advanced boxscore for game 57 of 208
# Scraping advanced boxscore for game 58 of 208
# Scraping advanced boxscore for game 59 of 208
# Scraping advanced boxscore for game 60 of 208
# Scraping advanced boxscore for game 61 of 208
# Scraping advanced boxscore for game 62 of 208
# Scraping advanced boxscore for game 63 of 208
# Scraping advanced boxscore for game 64 of 208
# Scraping advanced boxscore for game 65 of 208
# Scraping advanced boxscore for game 66 of 208
# Scraping advanced boxscore for game 67 of 208
# Scraping advanced boxscore for game 68 of 208
# Scraping advanced boxscore for game 69 of 208
# Scraping advanced boxscore for game 70 of 208
# Scraping advanced boxscore for game 71 of 208
# Scraping advanced boxscore for game 72 of 208
# Scraping advanced boxscore for game 73 of 208
# Scraping advanced boxscore for game 74 of 208
# Scraping advanced boxscore for game 75 of 208
# Scraping advanced boxscore for game 76 of 208
# Scraping advanced boxscore for game 77 of 208
# Scraping advanced boxscore for game 78 of 208
# Scraping advanced boxscore for game 79 of 208
# Scraping advanced boxscore for game 80 of 208
# Scraping advanced boxscore for game 81 of 208
# Scraping advanced boxscore for game 82 of 208
# Scraping advanced boxscore for game 83 of 208
# Scraping advanced boxscore for game 84 of 208
# Scraping advanced boxscore for game 85 of 208
# Scraping advanced boxscore for game 86 of 208
# Scraping advanced boxscore for game 87 of 208
# Scraping advanced boxscore for game 88 of 208
# Scraping advanced boxscore for game 89 of 208
# Scraping advanced boxscore for game 90 of 208
# Scraping advanced boxscore for game 91 of 208
# Scraping advanced boxscore for game 92 of 208
# Scraping advanced boxscore for game 93 of 208
# Scraping advanced boxscore for game 94 of 208
# Scraping advanced boxscore for game 95 of 208
# Scraping advanced boxscore for game 96 of 208
# Scraping advanced boxscore for game 97 of 208
# Scraping advanced boxscore for game 98 of 208
# Scraping advanced boxscore for game 99 of 208
# Scraping advanced boxscore for game 100 of 208
# Scraping advanced boxscore for game 101 of 208
# Scraping advanced boxscore for game 102 of 208
# Scraping advanced boxscore for game 103 of 208
# Scraping advanced boxscore for game 104 of 208
# Scraping advanced boxscore for game 105 of 208
# Scraping advanced boxscore for game 106 of 208
# Scraping advanced boxscore for game 107 of 208
# Scraping advanced boxscore for game 108 of 208
# Scraping advanced boxscore for game 109 of 208
# Scraping advanced boxscore for game 110 of 208
# Scraping advanced boxscore for game 111 of 208
# Scraping advanced boxscore for game 112 of 208
# Scraping advanced boxscore for game 113 of 208
# Scraping advanced boxscore for game 114 of 208
# Scraping advanced boxscore for game 115 of 208
# Scraping advanced boxscore for game 116 of 208
# Scraping advanced boxscore for game 117 of 208
# Scraping advanced boxscore for game 118 of 208
# Scraping advanced boxscore for game 119 of 208
# Scraping advanced boxscore for game 120 of 208
# Scraping advanced boxscore for game 121 of 208
# Scraping advanced boxscore for game 122 of 208
# Scraping advanced boxscore for game 123 of 208
# Scraping advanced boxscore for game 124 of 208
# Scraping advanced boxscore for game 125 of 208
# Scraping advanced boxscore for game 126 of 208
# Scraping advanced boxscore for game 127 of 208
# Scraping advanced boxscore for game 128 of 208
# Scraping advanced boxscore for game 129 of 208
# Scraping advanced boxscore for game 130 of 208
# Scraping advanced boxscore for game 131 of 208
# Scraping advanced boxscore for game 132 of 208
# Scraping advanced boxscore for game 133 of 208
# Scraping advanced boxscore for game 134 of 208
# Scraping advanced boxscore for game 135 of 208
# Scraping advanced boxscore for game 136 of 208
# Scraping advanced boxscore for game 137 of 208
# Scraping advanced boxscore for game 138 of 208
# Scraping advanced boxscore for game 139 of 208
# Scraping advanced boxscore for game 140 of 208
# Scraping advanced boxscore for game 141 of 208
# Scraping advanced boxscore for game 142 of 208
# Scraping advanced boxscore for game 143 of 208
# Scraping advanced boxscore for game 144 of 208
# Scraping advanced boxscore for game 145 of 208
# Scraping advanced boxscore for game 146 of 208
# Scraping advanced boxscore for game 147 of 208
# Scraping advanced boxscore for game 148 of 208
# Scraping advanced boxscore for game 149 of 208
# Scraping advanced boxscore for game 150 of 208
# Scraping advanced boxscore for game 151 of 208
# Scraping advanced boxscore for game 152 of 208
# Scraping advanced boxscore for game 153 of 208
# Scraping advanced boxscore for game 154 of 208
# Scraping advanced boxscore for game 155 of 208
# Scraping advanced boxscore for game 156 of 208
# Scraping advanced boxscore for game 157 of 208
# Scraping advanced boxscore for game 158 of 208
# Scraping advanced boxscore for game 159 of 208
# Scraping advanced boxscore for game 160 of 208
# Scraping advanced boxscore for game 161 of 208
# Scraping advanced boxscore for game 162 of 208
# Scraping advanced boxscore for game 163 of 208
# Scraping advanced boxscore for game 164 of 208
# Scraping advanced boxscore for game 165 of 208
# Scraping advanced boxscore for game 166 of 208
# Scraping advanced boxscore for game 167 of 208
# Scraping advanced boxscore for game 168 of 208
# Scraping advanced boxscore for game 169 of 208
# Scraping advanced boxscore for game 170 of 208
# Scraping advanced boxscore for game 171 of 208
# Scraping advanced boxscore for game 172 of 208
# Scraping advanced boxscore for game 173 of 208
# Scraping advanced boxscore for game 174 of 208
# Scraping advanced boxscore for game 175 of 208
# Scraping advanced boxscore for game 176 of 208
# Scraping advanced boxscore for game 177 of 208
# Scraping advanced boxscore for game 178 of 208
# Scraping advanced boxscore for game 179 of 208
# Scraping advanced boxscore for game 180 of 208
# Scraping advanced boxscore for game 181 of 208
# Scraping advanced boxscore for game 182 of 208
# Scraping advanced boxscore for game 183 of 208
# Scraping advanced boxscore for game 184 of 208
# Scraping advanced boxscore for game 185 of 208
# Scraping advanced boxscore for game 186 of 208
# Scraping advanced boxscore for game 187 of 208
# Scraping advanced boxscore for game 188 of 208
# Scraping advanced boxscore for game 189 of 208
# Scraping advanced boxscore for game 190 of 208
# Scraping advanced boxscore for game 191 of 208
# Scraping advanced boxscore for game 192 of 208
# Scraping advanced boxscore for game 193 of 208
# Scraping advanced boxscore for game 194 of 208
# Scraping advanced boxscore for game 195 of 208
# Scraping advanced boxscore for game 196 of 208
# Scraping advanced boxscore for game 197 of 208
# Scraping advanced boxscore for game 198 of 208
# Scraping advanced boxscore for game 199 of 208
# Scraping advanced boxscore for game 200 of 208
# Scraping advanced boxscore for game 201 of 208
# Scraping advanced boxscore for game 202 of 208
# Scraping advanced boxscore for game 203 of 208
# Scraping advanced boxscore for game 204 of 208
# Scraping advanced boxscore for game 205 of 208
# Scraping advanced boxscore for game 206 of 208
# Scraping advanced boxscore for game 207 of 208
# Scraping advanced boxscore for game 208 of 208
# Updated data with advanced stats saved to CSV!
